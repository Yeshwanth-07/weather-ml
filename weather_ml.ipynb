# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Dataset11-Weather-Data.csv')
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# Freezing Drizzle                              7
# Snow,Ice Pellets                              6
# Freezing Drizzle,Fog                          6
# Snow,Haze                                     5
# Freezing Fog                                  4
# Snow Showers,Fog                              4
# Moderate Snow                                 4
# Rain,Snow,Ice Pellets                         4
# Freezing Rain,Fog                             4
# Freezing Drizzle,Haze                         3
# Rain,Haze                                     3
# Thunderstorms,Rain                            3
# Thunderstorms,Rain Showers,Fog                3
# Freezing Rain,Haze                            2
# Drizzle,Snow                                  2
# Rain Showers,Snow Showers                     2
# Thunderstorms                                 2
# Moderate Snow,Blowing Snow                    2
# Rain Showers,Fog                              1
# Thunderstorms,Moderate Rain Showers,Fog       1
# Snow Pellets                                  1
# Rain,Snow,Fog                                 1
# Moderate Rain,Fog                             1
# Freezing Rain,Ice Pellets,Fog                 1
# Drizzle,Ice Pellets,Fog                       1
# Thunderstorms,Rain,Fog                        1
# Rain,Ice Pellets                              1
# Rain,Snow Grains                              1
# Thunderstorms,Heavy Rain Showers              1
# Freezing Rain,Snow Grains                     1
# Name: count, dtype: int64

# %%
data.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
#        'Drizzle,Ice Pellets,Fog', 'Drizzle,Snow', 'Rain,Ice Pellets',
#        'Drizzle,Snow,Fog', 'Rain,Snow Grains', 'Rain,Snow,Ice Pellets',
#        'Snow Showers,Fog', 'Moderate Snow,Blowing Snow'], dtype=object)

# %%
x = 'Thunderstorms,Moderate Rain Showers,Fog'
list_of_lists = [w.split() for w in x.split(',')]
list_of_lists
# Out:
# [['Thunderstorms'], ['Moderate', 'Rain', 'Showers'], ['Fog']]

# %%
from itertools import chain
flat_list = list(chain(*list_of_lists))
flat_list
# Out:
# ['Thunderstorms', 'Moderate', 'Rain', 'Showers', 'Fog']

# %%
def Create_List(x):
  list_of_lists = [w.split() for w in x.split(',')]
  flat_list = list(chain(*list_of_lists))
  return flat_list



def Get_weather(list1):
  if 'Rain' in list1 and 'Fog' in list1:
    return 'RAIN+FOG'
  elif 'Snow' in list1 and 'Rain' in list1:
    return 'RAIN+SNOW'
  elif 'Rain' in list1:
    return 'RAIN'
  elif 'Snow' in list1:
    return 'SNOW'
  elif 'Fog' in list1:
    return 'FOG'
  elif 'Clear' in list1:
    return 'CLEAR'
  elif 'Cloudy' in list1:
    return 'CLOUDY'
  else:
    return 'RAIN'

# %%
Create_List(x)
# Out:
# ['Thunderstorms', 'Moderate', 'Rain', 'Showers', 'Fog']

# %%
Get_weather(Create_List(x))
# Out:
# 'RAIN+FOG'

# %%
data['Std_Weather'] = data['Weather'].apply(lambda x: Get_weather(Create_List(x)))
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa               Weather Std_Weather
# 0               8.0     101.24                   Fog         FOG
# 1               8.0     101.24                   Fog         FOG
# 2               4.0     101.26  Freezing Drizzle,Fog         FOG
# 3               4.0     101.27  Freezing Drizzle,Fog         FOG
# 4               4.8     101.23                   Fog         FOG
# ...             ...        ...                   ...         ...
# 8779            9.7     100.13                  Snow        SNOW
# 8780            9.7     100.03                  Snow        SNOW
# 8781            4.8      99.95                  Snow        SNOW
# 8782            9.7      99.91                  Snow        SNOW
# 8783           11.3      99.89                  Snow        SNOW
#
# [8784 rows x 9 columns]

# %%
data.Std_Weather.value_counts()
# Out:
# Std_Weather
# CLOUDY       3797
# CLEAR        3432
# RAIN          603
# SNOW          556
# FOG           241
# RAIN+FOG      129
# RAIN+SNOW      26
# Name: count, dtype: int64

# %%
cloudy_df = data[data['Std_Weather'] == 'CLOUDY'].sample(600)
cloudy_df
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 580    1/25/2012 4:00    -0.7              -6.0         67               24
# 2834   4/28/2012 2:00    -0.4              -8.1         56               22
# 2001   3/24/2012 9:00     3.0             -11.2         34               22
# 8354  12/14/2012 2:00    -0.6              -3.2         83               15
# 1364  2/26/2012 20:00    -7.9             -16.4         50               11
# ...               ...     ...               ...        ...              ...
# 5376   8/12/2012 0:00    20.1              18.9         93                4
# 4775  7/17/2012 23:00    21.6              18.1         80               13
# 6031    9/8/2012 7:00    21.0              17.8         82               20
# 1269  2/22/2012 21:00     2.3              -0.9         79               15
# 1521    3/4/2012 9:00    -6.3             -13.5         57               15
#
#       Visibility_km  Press_kPa        Weather Std_Weather
# 580            25.0     101.52         Cloudy      CLOUDY
# 2834           25.0     101.50         Cloudy      CLOUDY
# 2001           48.3     101.94         Cloudy      CLOUDY
# 8354           25.0     101.59         Cloudy      CLOUDY
# 1364           25.0     102.64         Cloudy      CLOUDY
# ...             ...        ...            ...         ...
# 5376           19.3     100.70  Mostly Cloudy      CLOUDY
# 4775           25.0     100.25  Mostly Cloudy      CLOUDY
# 6031           19.3      99.77         Cloudy      CLOUDY
# 1269           25.0      99.33  Mostly Cloudy      CLOUDY
# 1521           24.1      99.95         Cloudy      CLOUDY
#
# [600 rows x 9 columns]

# %%
clear_df = data[data['Std_Weather'] == 'CLEAR'].sample(600)
clear_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 3016    5/5/2012 16:00    16.0              -2.4         28               17
# 465     1/20/2012 9:00   -12.2             -18.1         61               32
# 7684   11/16/2012 4:00    -6.7              -8.1         90                0
# 1410   2/28/2012 18:00    -5.3             -12.5         57               17
# 7847  11/22/2012 23:00     4.4              -1.3         66               11
# ...                ...     ...               ...        ...              ...
# 4843   7/20/2012 19:00    23.5               7.6         36                7
# 4577    7/9/2012 17:00    24.2               5.3         29               11
# 3464    5/24/2012 8:00    21.1              14.6         66                0
# 2583   4/17/2012 15:00    12.7              -0.5         40               30
# 344     1/15/2012 8:00   -23.3             -28.5         62                7
#
#       Visibility_km  Press_kPa       Weather Std_Weather
# 3016           48.3     101.51         Clear       CLEAR
# 465            24.1     101.59         Clear       CLEAR
# 7684           19.3     102.42         Clear       CLEAR
# 1410           24.1     102.56         Clear       CLEAR
# 7847           25.0     101.11  Mainly Clear       CLEAR
# ...             ...        ...           ...         ...
# 4843           48.3     101.33  Mainly Clear       CLEAR
# 4577           48.3     100.98  Mainly Clear       CLEAR
# 3464           24.1     101.54  Mainly Clear       CLEAR
# 2583           48.3     101.63  Mainly Clear       CLEAR
# 344            24.1     102.45         Clear       CLEAR
#
# [600 rows x 9 columns]

# %%
rain_df = data[data['Std_Weather'] == 'RAIN']
rain_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 18      1/1/2012 18:00     3.8               1.0         82               15
# 19      1/1/2012 19:00     3.1               1.3         88               15
# 22      1/1/2012 22:00     4.4               1.9         84               24
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 154     1/7/2012 10:00    -5.7              -8.0         84                7
# ...                ...     ...               ...        ...              ...
# 8538  12/21/2012 18:00     1.4               0.3         92               46
# 8539  12/21/2012 19:00     2.3               1.1         92               37
# 8540  12/21/2012 20:00     2.4               1.7         95               15
# 8541  12/21/2012 21:00     1.3               0.4         94               22
# 8545   12/22/2012 1:00     1.2               0.1         92               30
#
#       Visibility_km  Press_kPa        Weather Std_Weather
# 18             12.9      99.74           Rain        RAIN
# 19             12.9      99.68           Rain        RAIN
# 22             19.3      99.32   Rain Showers        RAIN
# 24             25.0      99.26   Rain Showers        RAIN
# 154             8.0     100.13  Freezing Rain        RAIN
# ...             ...        ...            ...         ...
# 8538           25.0      97.56           Rain        RAIN
# 8539           11.3      97.52           Rain        RAIN
# 8540            9.7      97.58           Rain        RAIN
# 8541            9.7      97.64           Rain        RAIN
# 8545           12.9      97.84        Drizzle        RAIN
#
# [603 rows x 9 columns]

# %%
snow_df = data[data['Std_Weather'] == 'SNOW']
snow_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather Std_Weather
# 41             25.0      99.66  Snow Showers        SNOW
# 44             25.0     100.07  Snow Showers        SNOW
# 45             25.0     100.15  Snow Showers        SNOW
# 47             19.3     100.27  Snow Showers        SNOW
# 48             25.0     100.35  Snow Showers        SNOW
# ...             ...        ...           ...         ...
# 8779            9.7     100.13          Snow        SNOW
# 8780            9.7     100.03          Snow        SNOW
# 8781            4.8      99.95          Snow        SNOW
# 8782            9.7      99.91          Snow        SNOW
# 8783           11.3      99.89          Snow        SNOW
#
# [556 rows x 9 columns]

# %%
weather_df = pd.concat([cloudy_df,clear_df,rain_df,snow_df],axis=0)
weather_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 580     1/25/2012 4:00    -0.7              -6.0         67               24
# 2834    4/28/2012 2:00    -0.4              -8.1         56               22
# 2001    3/24/2012 9:00     3.0             -11.2         34               22
# 8354   12/14/2012 2:00    -0.6              -3.2         83               15
# 1364   2/26/2012 20:00    -7.9             -16.4         50               11
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather Std_Weather
# 580            25.0     101.52  Cloudy      CLOUDY
# 2834           25.0     101.50  Cloudy      CLOUDY
# 2001           48.3     101.94  Cloudy      CLOUDY
# 8354           25.0     101.59  Cloudy      CLOUDY
# 1364           25.0     102.64  Cloudy      CLOUDY
# ...             ...        ...     ...         ...
# 8779            9.7     100.13    Snow        SNOW
# 8780            9.7     100.03    Snow        SNOW
# 8781            4.8      99.95    Snow        SNOW
# 8782            9.7      99.91    Snow        SNOW
# 8783           11.3      99.89    Snow        SNOW
#
# [2359 rows x 9 columns]

# %%
weather_df.Std_Weather.value_counts()
# Out:
# Std_Weather
# RAIN      603
# CLOUDY    600
# CLEAR     600
# SNOW      556
# Name: count, dtype: int64

# %%
weather_df.drop(columns=['Date/Time','Weather'],axis=1,inplace=True)
weather_df
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 580     -0.7              -6.0         67               24           25.0
# 2834    -0.4              -8.1         56               22           25.0
# 2001     3.0             -11.2         34               22           48.3
# 8354    -0.6              -3.2         83               15           25.0
# 1364    -7.9             -16.4         50               11           25.0
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa Std_Weather
# 580      101.52      CLOUDY
# 2834     101.50      CLOUDY
# 2001     101.94      CLOUDY
# 8354     101.59      CLOUDY
# 1364     102.64      CLOUDY
# ...         ...         ...
# 8779     100.13        SNOW
# 8780     100.03        SNOW
# 8781      99.95        SNOW
# 8782      99.91        SNOW
# 8783      99.89        SNOW
#
# [2359 rows x 7 columns]

# %%
weather_df.isnull().sum()
# Out:
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Std_Weather         0
# dtype: int64

# %%
weather_df['Temp_C'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather_df['Dew Point Temp_C'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather_df['Rel Hum_%'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather_df['Wind Speed_km/h'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather_df['Visibility_km'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
weather_df['Press_kPa'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
weather_df['Std_Weather'] = label_encoder.fit_transform(weather_df['Std_Weather'])
weather_df
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 580     -0.7              -6.0         67               24           25.0
# 2834    -0.4              -8.1         56               22           25.0
# 2001     3.0             -11.2         34               22           48.3
# 8354    -0.6              -3.2         83               15           25.0
# 1364    -7.9             -16.4         50               11           25.0
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa  Std_Weather
# 580      101.52            1
# 2834     101.50            1
# 2001     101.94            1
# 8354     101.59            1
# 1364     102.64            1
# ...         ...          ...
# 8779     100.13            3
# 8780     100.03            3
# 8781      99.95            3
# 8782      99.91            3
# 8783      99.89            3
#
# [2359 rows x 7 columns]

# %%
label_encoder.classes_
# Out:
# array(['CLEAR', 'CLOUDY', 'RAIN', 'SNOW'], dtype=object)

# %%
weather_df['Std_Weather'].value_counts()
# Out:
# Std_Weather
# 2    603
# 1    600
# 0    600
# 3    556
# Name: count, dtype: int64

# %%
cols = ['Temp_C','Dew Point Temp_C','Rel Hum_%','Wind Speed_km/h','Visibility_km','Press_kPa','Std_Weather']
cor_matrix = weather_df[cols].corr()
cor_matrix
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.940404  -0.252952        -0.131153
# Dew Point Temp_C  0.940404          1.000000   0.084177        -0.129552
# Rel Hum_%        -0.252952          0.084177   1.000000         0.022104
# Wind Speed_km/h  -0.131153         -0.129552   0.022104         1.000000
# Visibility_km     0.393186          0.182868  -0.657525        -0.136531
# Press_kPa        -0.103613         -0.220519  -0.347067        -0.399796
# Std_Weather      -0.391222         -0.244363   0.488656         0.280265
#
#                   Visibility_km  Press_kPa  Std_Weather
# Temp_C                 0.393186  -0.103613    -0.391222
# Dew Point Temp_C       0.182868  -0.220519    -0.244363
# Rel Hum_%             -0.657525  -0.347067     0.488656
# Wind Speed_km/h       -0.136531  -0.399796     0.280265
# Visibility_km          1.000000   0.321567    -0.652446
# Press_kPa              0.321567   1.000000    -0.387099
# Std_Weather           -0.652446  -0.387099     1.000000

# %%
sns.heatmap(cor_matrix,annot=True)
# Out:
# <Axes: >

# %%
X = weather_df.drop(['Std_Weather'],axis=1)
X
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 580     -0.7              -6.0         67               24           25.0
# 2834    -0.4              -8.1         56               22           25.0
# 2001     3.0             -11.2         34               22           48.3
# 8354    -0.6              -3.2         83               15           25.0
# 1364    -7.9             -16.4         50               11           25.0
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa
# 580      101.52
# 2834     101.50
# 2001     101.94
# 8354     101.59
# 1364     102.64
# ...         ...
# 8779     100.13
# 8780     100.03
# 8781      99.95
# 8782      99.91
# 8783      99.89
#
# [2359 rows x 6 columns]

# %%
Y = weather_df['Std_Weather']
Y
# Out:
# 580     1
# 2834    1
# 2001    1
# 8354    1
# 1364    1
#        ..
# 8779    3
# 8780    3
# 8781    3
# 8782    3
# 8783    3
# Name: Std_Weather, Length: 2359, dtype: int64

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_std = scaler.fit_transform(X)
x_std
# Out:
# array([[-0.62990212, -0.70313167, -0.3280731 ,  0.77693741,  0.14109214,
#          0.76184609],
#        [-0.60347477, -0.90368694, -1.01373425,  0.56544475,  0.14109214,
#          0.74057185],
#        [-0.30396487, -1.19974472, -2.38505654,  0.56544475,  1.96930285,
#          1.20860521],
#        ...,
#        [-0.61228389, -0.27337037,  1.29258053,  1.19992272, -1.44388024,
#         -0.90818205],
#        [-0.58585654, -0.30202112,  1.0432492 ,  1.19992272, -1.05940674,
#         -0.95073054],
#        [-0.56823831, -0.33067188,  0.8562507 ,  1.41141537, -0.93386437,
#         -0.97200478]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_std,Y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1887, 6), (472, 6))

# %%
y_test
# Out:
# 5071    0
# 8654    1
# 773     3
# 7016    2
# 991     3
#        ..
# 1764    3
# 3195    1
# 3546    2
# 1318    2
# 8555    3
# Name: Std_Weather, Length: 472, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 2, 3, 1, 3, 3, 0, 3, 1, 3, 1, 0, 0, 2, 1, 3, 1, 2, 0, 3, 0, 3,
#        2, 2, 2, 1, 2, 3, 1, 3, 3, 2, 2, 2, 2, 0, 0, 3, 1, 2, 2, 2, 2, 3,
#        0, 1, 1, 3, 0, 2, 0, 1, 1, 2, 1, 3, 1, 2, 1, 1, 0, 0, 2, 1, 3, 2,
#        2, 2, 1, 1, 0, 1, 1, 2, 1, 1, 2, 2, 0, 1, 3, 3, 2, 2, 2, 2, 3, 0,
#        0, 1, 0, 0, 2, 3, 0, 1, 0, 3, 3, 1, 3, 3, 3, 2, 3, 0, 0, 2, 1, 0,
#        1, 0, 0, 3, 2, 1, 2, 0, 2, 1, 0, 2, 0, 3, 2, 2, 3, 0, 3, 1, 2, 0,
#        2, 0, 2, 2, 3, 2, 1, 3, 1, 0, 0, 2, 1, 1, 0, 3, 0, 0, 3, 1, 2, 1,
#        0, 3, 1, 0, 0, 3, 3, 0, 2, 1, 1, 2, 2, 0, 0, 2, 1, 0, 2, 2, 1, 2,
#        0, 2, 2, 1, 1, 1, 1, 1, 2, 1, 2, 0, 0, 2, 1, 1, 0, 2, 1, 3, 3, 0,
#        0, 1, 2, 2, 1, 1, 2, 2, 3, 1, 3, 1, 2, 0, 0, 0, 0, 0, 0, 0, 1, 2,
#        3, 1, 1, 0, 3, 0, 2, 3, 2, 2, 2, 2, 2, 1, 2, 3, 1, 2, 0, 0, 2, 3,
#        1, 0, 1, 2, 2, 0, 3, 2, 2, 0, 0, 2, 2, 2, 0, 0, 3, 0, 2, 2, 0, 1,
#        1, 3, 0, 2, 3, 0, 2, 1, 1, 3, 0, 2, 3, 3, 3, 3, 0, 0, 2, 0, 3, 1,
#        2, 2, 1, 1, 2, 2, 1, 2, 1, 3, 0, 1, 1, 2, 2, 3, 1, 1, 3, 2, 0, 2,
#        0, 3, 2, 1, 2, 0, 1, 3, 2, 3, 0, 2, 1, 3, 3, 3, 2, 2, 3, 0, 2, 2,
#        0, 2, 0, 3, 0, 2, 0, 2, 3, 0, 0, 1, 2, 3, 0, 0, 3, 1, 1, 1, 0, 0,
#        3, 3, 2, 1, 0, 1, 0, 1, 3, 1, 2, 0, 0, 0, 3, 0, 2, 2, 3, 1, 0, 1,
#        3, 3, 3, 0, 0, 0, 0, 3, 2, 0, 1, 2, 3, 0, 2, 1, 1, 2, 2, 2, 2, 0,
#        0, 3, 3, 2, 2, 1, 1, 3, 1, 2, 0, 1, 2, 2, 2, 3, 1, 2, 1, 1, 0, 2,
#        0, 1, 0, 1, 0, 1, 1, 0, 3, 3, 1, 3, 0, 1, 2, 3, 1, 0, 0, 0, 1, 2,
#        0, 3, 0, 1, 2, 1, 2, 0, 0, 2, 2, 3, 3, 3, 2, 1, 3, 2, 3, 0, 1, 3,
#        1, 0, 2, 2, 2, 2, 0, 1, 3, 3])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,y_pred)
# Out:
# 0.5783898305084746

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54       118
#            1       0.38      0.34      0.36       128
#            2       0.67      0.73      0.70       126
#            3       0.74      0.72      0.73       100
#
#     accuracy                           0.58       472
#    macro avg       0.58      0.59      0.58       472
# weighted avg       0.57      0.58      0.57       472

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier
mrf = RandomForestClassifier()

# %%
mrf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = mrf.predict(x_test)
rf_pred
# Out:
# array([0, 1, 3, 2, 3, 3, 1, 3, 1, 3, 2, 0, 1, 1, 1, 3, 2, 2, 1, 3, 0, 0,
#        1, 2, 2, 0, 2, 3, 2, 3, 3, 0, 0, 2, 2, 0, 0, 3, 3, 2, 2, 2, 1, 3,
#        3, 1, 1, 3, 0, 2, 1, 0, 3, 2, 0, 3, 1, 2, 2, 1, 1, 1, 2, 1, 3, 2,
#        2, 2, 3, 0, 0, 1, 2, 2, 0, 1, 2, 2, 0, 1, 3, 3, 2, 2, 2, 2, 3, 0,
#        1, 1, 1, 0, 2, 3, 0, 1, 0, 0, 2, 1, 3, 3, 3, 2, 3, 0, 2, 1, 3, 0,
#        0, 0, 2, 3, 2, 0, 2, 3, 2, 2, 0, 2, 1, 3, 2, 2, 3, 0, 3, 1, 2, 0,
#        3, 2, 0, 2, 3, 2, 1, 3, 1, 0, 0, 2, 0, 3, 1, 3, 3, 1, 3, 2, 2, 1,
#        1, 3, 0, 0, 1, 3, 3, 1, 2, 1, 1, 0, 2, 0, 0, 2, 0, 0, 2, 2, 0, 2,
#        0, 2, 2, 2, 1, 1, 0, 0, 2, 0, 2, 0, 0, 2, 2, 1, 2, 1, 0, 0, 3, 1,
#        0, 1, 2, 2, 0, 3, 1, 2, 3, 0, 3, 2, 2, 0, 0, 1, 0, 0, 3, 0, 2, 2,
#        3, 0, 1, 0, 3, 0, 2, 3, 2, 2, 2, 2, 1, 0, 2, 1, 0, 2, 0, 0, 2, 3,
#        0, 0, 0, 2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 0, 1, 3, 0, 1, 1, 0, 2,
#        2, 3, 0, 2, 3, 3, 2, 1, 1, 3, 0, 2, 3, 3, 3, 3, 0, 0, 2, 0, 3, 2,
#        2, 1, 1, 0, 2, 2, 0, 2, 1, 3, 0, 1, 1, 1, 2, 3, 1, 0, 3, 0, 0, 2,
#        1, 3, 2, 0, 2, 0, 0, 3, 2, 3, 1, 0, 1, 3, 3, 1, 0, 2, 3, 1, 2, 2,
#        1, 2, 0, 3, 0, 1, 0, 2, 3, 0, 0, 1, 2, 3, 1, 3, 3, 1, 0, 0, 0, 0,
#        3, 3, 3, 2, 0, 1, 0, 1, 3, 0, 1, 0, 2, 0, 3, 0, 2, 2, 3, 1, 0, 1,
#        3, 3, 3, 1, 0, 0, 0, 3, 2, 0, 3, 1, 3, 0, 2, 1, 0, 2, 2, 2, 2, 1,
#        0, 3, 3, 2, 2, 1, 1, 3, 1, 2, 0, 1, 2, 2, 2, 3, 2, 2, 2, 0, 0, 2,
#        0, 0, 0, 1, 0, 1, 0, 0, 3, 3, 0, 3, 0, 1, 1, 3, 0, 3, 0, 0, 1, 2,
#        0, 3, 0, 0, 2, 0, 0, 0, 1, 2, 2, 3, 3, 0, 2, 0, 1, 2, 3, 0, 1, 3,
#        2, 0, 2, 2, 2, 3, 0, 0, 3, 3])

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.6694915254237288

# %%
param_grid = {
    'n_estimators': [25,50,100,150],
    'max_features': ['sqrt','log2','None'],
    'max_depth': [3,6,9],
    'max_leaf_nodes': [3,6,9]
}

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
param_distributions = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
random_search = RandomizedSearchCV(
    estimator=mrf,
    param_distributions=param_distributions,
    n_iter=20,
    scoring='accuracy',
    cv=5,
    random_state=42,
    n_jobs=-1
)

# %%
random_search.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 10, 20, 30],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [10, 50, 100, 200]},
#                    random_state=42, scoring='accuracy')

# %%
print("Best parameters found: ", random_search.best_params_)
print("Best cross-validation score: ", random_search.best_score_)
# Out:
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 20, 'bootstrap': True}
# Best cross-validation score:  0.6889267820302303

# %%
model_random = RandomForestClassifier(n_estimators=200,min_samples_split=2,min_samples_leaf=1,max_depth=20,bootstrap=True)
model_random.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200)

# %%
# Select the first row of x_test
single_row = x_test[3].reshape(1, -1)  # Reshape to ensure it has the correct shape for prediction

# Predict the label for this single row
y_pred_single = model_random.predict(single_row)

print("Predicted Label for Single Row:", y_pred_single[0])
# Out:
# Predicted Label for Single Row: 2

# %%
accuracy_score(y_test,y_pred_random)
# Out:
# 0.6567796610169492
